# %%
import pandas as pd
import numpy as np

# %%
from libray import *

# %%
x_train, y_train,x_val , y_val, x_test , y_test , x_val_bal , y_val_bal , x_test_bal , y_test_bal= read_data()

# %%
x_train.shape
# Out:
# (55748, 8)

# %%
x_val.shape
# Out:
# (157767, 8)

# %%
x_test.shape
# Out:
# (19011, 8)

# %%
path1 = "../data/snorkel_train_gold_set.csv"
df_gold = pd.read_csv(path1)

# %%
df_gold.shape
# Out:
# (4224704, 41)

# %%
df_gold.describe()
# Out:
#             AP_DARS      AP_DDG_W     AP_DFIRE2    AP_GOAP_DF        AP_MPS  \
# count  4.224704e+06  4.224704e+06  4.224704e+06  4.224704e+06  4.224704e+06
# mean   3.514619e-01  5.441503e-01  7.814758e-01  6.923200e-01  4.317327e-01
# std    1.830553e-01  1.379709e-01  2.194867e+00  2.029206e-01  1.147525e-01
# min   -2.419480e+00 -2.348827e+00 -7.379163e+01 -1.947251e+00 -8.650817e-01
# 25%    2.682682e-01  4.781854e-01  6.001445e-01  6.025248e-01  3.659321e-01
# 50%    3.739824e-01  5.683341e-01  7.068742e-01  7.192729e-01  4.398112e-01
# 75%    4.663335e-01  6.372125e-01  7.954716e-01  8.177797e-01  5.077868e-01
# max    1.108584e+00  1.000000e+00  1.306161e+02  1.070333e+00  1.940849e+00
#
#             AP_PISA     AP_dDFIRE          AlAr          ArAr    BSA_Apolar  \
# count  4.224704e+06  4.224704e+06  4.224704e+06  4.224704e+06  4.224704e+06
# mean   2.003255e-01  6.246241e-01  1.955294e-01  1.030122e-01  3.636757e-01
# ...

# %%
df_gold.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4224704 entries, 0 to 4224703
# Data columns (total 41 columns):
#  #   Column        Dtype
# ---  ------        -----
#  0   Conf          object
#  1   AP_DARS       float64
#  2   AP_DDG_W      float64
#  3   AP_DFIRE2     float64
#  4   AP_GOAP_DF    float64
#  5   AP_MPS        float64
#  6   AP_PISA       float64
#  7   AP_dDFIRE     float64
#  8   AlAr          float64
#  9   ArAr          float64
#  10  BSA_Apolar    float64
#  11  CONSRANK_val  float64
#  12  CP_BFKV       float64
#  13  CP_BT         float64
#  14  CP_D1         float64
#  15  CP_HLPL       float64
#  16  CP_MJ2h       float64
#  17  CP_MJ3h       float64
#  18  CP_MJPL       float64
#  19  CP_Qp         float64
#  20  CP_RMFCA      float64
#  21  CP_RMFCEN1    float64
#  22  CP_RMFCEN2    float64
#  23  CP_SKOIP      float64
#  24  CP_SKOb       float64
#  25  CP_TB         float64
#  26  CP_TD         float64
#  27  CP_TEl        float64
# ...

# %%
df_gold.shape[0] - x_train.shape[0]
# Out:
# 4168956

# %%
df_gold[["NNC","label_binary"]]
# Out:
#               NNC  label_binary
# 0        1.000261             1
# 1        1.000261             1
# 2       -0.000194             0
# 3       -0.000194             0
# 4       -0.000194             0
# ...           ...           ...
# 4224699  0.995129             1
# 4224700  0.970205             1
# 4224701  0.967472             0
# 4224702  0.104020             0
# 4224703  0.196939             0
#
# [4224704 rows x 2 columns]

# %%
x_train
# Out:
#                    CONSRANK_val   CP_HLPL   CP_MJ3h     DDG_V  CP_RMFCA  \
# Conf
# F_1A2K_1488_I.pdb      0.006856  0.666667  0.512844  0.760255  0.657061
# F_1A2K_1598_I.pdb      0.007113  0.794183  0.691743  0.786148  0.808949
# F_1A2K_161_I.pdb       0.017525  0.559284  0.569266  0.650389  0.631666
# F_1A2K_1631_I.pdb      0.007103  0.733781  0.617431  0.750583  0.768745
# F_1A2K_1798_A.pdb      0.067550  0.601790  0.589908  0.717533  0.760225
# ...                         ...       ...       ...       ...       ...
# Z_9QFW_9803_A.pdb      0.172167  0.364653  0.405963  0.511496  0.580501
# Z_9QFW_980_A.pdb       0.129222  0.344519  0.387156  0.544016  0.571142
# Z_9QFW_983_I.pdb       0.116543  0.212528  0.403670  0.472553  0.353631
# Z_9QFW_9898_I.pdb      0.048838  0.469799  0.388073  0.525382  0.599926
# Z_BOYV_8458_I.pdb      0.062794  0.514541  0.352294  0.603595  0.620842
#
#                    AP_GOAP_DF       NNC   RFC
# Conf
# ...
